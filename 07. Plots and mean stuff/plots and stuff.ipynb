# %%
from mpl_toolkits import mplot3d
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np

# %%
#scatter plot
tips = sns.load_dataset("tips")
plt.scatter(tips["total_bill"], tips["tip"])
plt.show()

# %%
#box plot
fig = sns.boxplot(x = tips['total_bill'])
plt.show()

# %%
#heatmap
my_map = np.random.randn(10, 10)
plt.imshow(my_map)
plt.colorbar()
plt.show()

# %%
#contour plot
x = np.linspace(-3, 3, 100)
y = np.linspace(-3, 3, 100)
X,Y = np.meshgrid(x, y)
Z = np.sqrt(X**2+Y**2)
fig, ax = plt.subplots(1, 1)
p = ax.contour(X, Y, Z)
fig.colorbar(p)
plt.show()

# %%
#3d surface plot
x = np.outer(np.linspace(-3, 3, 32), np.ones(32))
y = x.copy().T
z = np.cos(x**2)+np.cos(y**2)
fig = plt.figure(figsize = (13, 6))
ax = plt.axes(projection = '3d')
ax.plot_surface(x, y, z) 
plt.show()

# %%
#mean, variance, standard deviation
heights = np.random.normal(1.90, 0.1, 25)
heights = np.round(heights, 2)
print(heights)
print(f"mean: {heights.mean()}")
print("variance: ", heights.var())
print("standard deviation ", heights.std())
# Out:
# [1.74 1.94 2.01 1.83 1.78 1.93 1.78 1.9  1.81 1.93 2.02 1.97 2.03 1.9
#  1.77 1.92 2.01 1.8  1.83 1.82 1.8  1.75 2.08 1.98 2.  ]
# mean: 1.8932
# variance:  0.009997759999999993
# standard deviation  0.09998879937272971
