# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
# %matplotlib notebook

# %%
df=pd.read_csv(r'data/iris.csv')

# %%
df.columns=np.array(['Sepel Length', 'Sepal width', 'Petal length', 'Petal width', 'Class'])

# %%
df.head()
# Out:
#    Sepel Length  Sepal width  Petal length  Petal width        Class
# 0           4.9          3.0           1.4          0.2  Iris-setosa
# 1           4.7          3.2           1.3          0.2  Iris-setosa
# 2           4.6          3.1           1.5          0.2  Iris-setosa
# 3           5.0          3.6           1.4          0.2  Iris-setosa
# 4           5.4          3.9           1.7          0.4  Iris-setosa

# %%
df.tail()
# Out:
#      Sepel Length  Sepal width  Petal length  Petal width           Class
# 144           6.7          3.0           5.2          2.3  Iris-virginica
# 145           6.3          2.5           5.0          1.9  Iris-virginica
# 146           6.5          3.0           5.2          2.0  Iris-virginica
# 147           6.2          3.4           5.4          2.3  Iris-virginica
# 148           5.9          3.0           5.1          1.8  Iris-virginica

# %%
df.describe()
# Out:
#        Sepel Length  Sepal width  Petal length  Petal width
# count    149.000000   149.000000    149.000000   149.000000
# mean       5.848322     3.054362      3.773826     1.206040
# std        0.828594     0.435810      1.760543     0.760354
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.400000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df['Sepal width'].describe()
# Out:
# count    149.000000
# mean       3.054362
# std        0.435810
# min        2.000000
# 25%        2.800000
# 50%        3.000000
# 75%        3.300000
# max        4.400000
# Name: Sepal width, dtype: float64

# %%
df.dtypes
# Out:
# Sepel Length    float64
# Sepal width     float64
# Petal length    float64
# Petal width     float64
# Class            object
# dtype: object

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <img src="data:image/png;base64,..." width="834">

# %%
# Positive correlation
sns.lmplot(x='Petal width', y='Petal length', data=df)
# Out:
# <img src="data:image/png;base64,..." width="932">

# %%
# Negative correlation
sns.lmplot(x='Sepal width', y='Petal length', data=df)
# Out:
# <img src="data:image/png;base64,..." width="943">
